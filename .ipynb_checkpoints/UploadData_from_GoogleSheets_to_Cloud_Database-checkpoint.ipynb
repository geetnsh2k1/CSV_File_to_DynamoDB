# %%
import boto3
from boto3.dynamodb.conditions import Key, Attr
import pandas as pd
import gspread
import numpy as np

# %%
def establish_connection(cred_file='./cred.json'):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        response['data'] = gspread.service_account(cred_file)
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def get_sheet(gc: gspread.service_account, key, worksheet=None):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        sheet = gc.open(key)
        if worksheet == None:
            worksheets = sheet.worksheets()
            if len(worksheets) >= 1:
                worksheet = worksheets[0].title
            else:
                raise Exception("Error: no worksheet available to load!")
        response['data'] = sheet.worksheet(worksheet)
            
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def convert_records_to_dataframe(worksheet):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        df = pd.DataFrame(worksheet.get_all_records())
        df = df.set_index('name')
        df = df.replace(r'^\s*$', np.nan, regex=True)
        df.fillna("None", inplace=True)
        response['data'] = df
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def create_dynamodb_resourse(service_name, region_name, aws_access_key_id, aws_secret_access_key):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        response['data'] = boto3.resource(
            service_name=service_name,
            region_name=region_name,
            aws_access_key_id=aws_access_key_id,
            aws_secret_access_key=aws_secret_access_key
        )
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def get_table(dynamodb, TableName):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        table = dynamodb.Table(TableName)
        test = table.creation_date_time # used to check if table exists or not
        response['data'] = table
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def put_data(table, data):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        response['data'] = table.put_item(Item=data)
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def put_batch_data(table, data):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = []
    try:
        with table.batch_writer() as batch:
            for d in data:
                try:
                    batch.put_item(Item=d)
                    print(d['name'], 'successfully uploaded!')
                except Exception as e:
                    response['data'].append(d)
                    print(d['name'], 'error:', e)
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def delete_item(table, Key):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        response['data']=table.delete_item(Key=Key)
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def create_data_packet(df, i):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = None
    try:
        obj = df.iloc[i].to_dict()
        obj['name'] = df.index[i]
        response['data']=obj
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def create_data_batches(df, packets, i=0):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = []
    response['failed'] = []
    try:
        while packets and i<len(df):
            obj = create_data_packet(df, i)
            if response['status'] == False:
                response['failed'].append(i)
            else:
                response['data'].append(obj['data'])
            packets -= 1
            i += 1
        response['i'] = i
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def get_index(service_name, region_name, aws_access_key_id, aws_secret_access_key, bucket_name, file):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = 0
    try:
        s3 = boto3.client(
                service_name = service_name,
                region_name = region_name,
                aws_access_key_id = aws_access_key_id,
                aws_secret_access_key = aws_secret_access_key
        )
        file = s3.get_object(Bucket=Bucket, Key=Key)['Body']
        data = file.read().decode()
        response['data'] = int(data)
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def update_index(service_name, region_name, aws_access_key_id, aws_secret_access_key, bucket_name, file, i):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    response['data'] = 0
    try:
        s3 = boto3.client(
                service_name = service_name,
                region_name = region_name,
                aws_access_key_id = aws_access_key_id,
                aws_secret_access_key = aws_secret_access_key
        )
        with open("index.txt", 'w') as f:
            f.write(str(i))
        s3.upload_file(Filename=file, Bucket=bucket_name, Key=file)
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
def main(service_name, region_name, aws_access_key_id, aws_secret_access_key, s3_service_name, s3_region_name, s3_aws_access_key_id, s3_aws_secret_access_key, s3_bucket_name, s3_file, TableName, packets, cred_file, key, worksheet=None):
    response = dict()
    response['status'] = True
    response['result'] = "Successfull"
    try:
        # establish a connection between our code and google sheet
        resp = establish_connection(cred_file)

        if resp['status'] == False:
            print('here')
            raise Exception(resp['result'])
        
        # get the particulat sheet object from all the google sheets
        resp = get_sheet(resp['data'], key, worksheet)

        if resp['status'] == False:
            raise Exception(resp['result'])

        # sheet records to dataframe
        resp = convert_records_to_dataframe(resp['data'])
        
        if resp['status'] == False:
                raise Exception(resp['result'])
        
        # dataframe of the google spreadsheet
        df = resp['data']
        
        # dynamodb object
        resp = create_dynamodb_resourse(service_name, region_name, aws_access_key_id, aws_secret_access_key)
        
        if resp['status'] == False:
                raise Exception(resp['result'])
        
        dynamodb = resp['data']
        
        # get "players" table access from the dynamodb server
        resp = get_table(dynamodb, TableName)
        
        if resp['status'] == False:
                raise Exception(resp['result'])
        
        table = resp['data']
        
        failed = []
        batches = []
        i = get_index(s3_service_name, s3_region_name, s3_aws_access_key_id, s3_aws_secret_access_key, s3_bucket_name, s3_file)['data']
        print(i)
        while i<len(df):
            resp = create_data_batches(df, packets, i)
            if resp['status'] == False:
                raise Exception(resp['result'])
            
            i = resp['i']
            failed.extend(resp['failed'])
            batches.extend(resp['data'])
            
            print(resp['data'], end='\n\n')
            
            data = batches[0:3]
            batches = batches[3:]
            resp = put_batch_data(table, data)
            if resp['status'] == False:
                raise Exception(resp['result'])
                
            batches.extend(resp['data'])
        
        while len(batches) > 0:
            data = batches[0:3]
            batches = batches[3:]
            resp = put_batch_data(table, data)
            if resp['status'] == False:
                raise Exception(resp['result'])
                
            batches.extend(resp['data'])
        
        response['failed'] = failed
        
        resp = update_index(s3_service_name, s3_region_name, s3_aws_access_key_id, s3_aws_secret_access_key, s3_bucket_name, s3_file, i)
        if resp['status'] == False:
                raise Exception(resp['result'])
        
#         for i in failed:
#             resp = create_data_packet(df, i)
#             if resp['status'] == False:
#                 raise Exception(resp['result'])
#                 break
#             failed.extend(resp['failed'])
#             resp = put_batch_data(table, data)
#             if resp['status'] == False:
#                 raise Exception(resp['result'])
#                 break
        
    except Exception as e:
        response['status'] = False
        response['result'] = e
    return response

# %%
cred_file = "cred.json"
key = "players"
worksheet = "dataset"

TableName = "Players"
packets = 1

service_name = "dynamodb"
region_name = "ap-south-1"
aws_access_key_id = "AKIAU5AT5CQR67O3F6AL"
aws_secret_access_key = "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"

s3_service_name = "s3"
s3_region_name = "us-east-2"
s3_aws_access_key_id = "AKIAU5AT5CQRYNL5DVMD"
s3_aws_secret_access_key = "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"

s3_bucket_name = "jsonawsbucket"
s3_file = "index.txt"

resp = main(service_name, region_name, aws_access_key_id, aws_secret_access_key, s3_service_name, s3_region_name, s3_aws_access_key_id, s3_aws_secret_access_key, s3_bucket_name, s3_file, TableName, packets, cred_file, key, worksheet)
print(resp)
# Out:
# 0
# [{'age': 39, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 78, 'runsScored': 2233, 'ballsFaced': 2102, "50's": 7, "100's": 6, 'wickets': 82, 'ballsBowled': 538, 'runsGiven': 734, "5's": 2, "10's": 0, 'exp': 30, 'name': 'P1'}]
#
# P1 successfully uploaded!
# [{'age': 21, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 41, 'runsScored': 1335, 'ballsFaced': 1295, "50's": 6, "100's": 3, 'wickets': 46, 'ballsBowled': 1386, 'runsGiven': 1609, "5's": 1, "10's": 2, 'exp': 22, 'name': 'P2'}]
#
# P2 successfully uploaded!
# [{'age': 27, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 41, 'runsScored': 80, 'ballsFaced': 94, "50's": 0, "100's": 0, 'wickets': 107, 'ballsBowled': 3523, 'runsGiven': 4369, "5's": 1, "10's": 7, 'exp': 39, 'name': 'P3'}]
#
# P3 successfully uploaded!
# [{'age': 28, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 138, 'runsScored': 6405, 'ballsFaced': 5965, "50's": 16, "100's": 29, 'wickets': 0, 'ballsBowled': 64, 'runsGiven': 223, "5's": 0, "10's": 0, 'exp': 51, 'name': 'P4'}]
#
# P4 successfully uploaded!
# [{'age': 19, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 21, 'runsScored': 788, 'ballsFaced': 790, "50's": 2, "100's": 4, 'wickets': 3, 'ballsBowled': 3, 'runsGiven': 8, "5's": 0, "10's": 0, 'exp': 14, 'name': 'P5'}]
#
# P5 successfully uploaded!
# [{'age': 17, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 22, 'runsScored': 560, 'ballsFaced': 553, "50's": 2, "100's": 1, 'wickets': 1, 'ballsBowled': 97, 'runsGiven': 216, "5's": 0, "10's": 0, 'exp': 10, 'name': 'P6'}]
#
# P6 successfully uploaded!
# [{'age': 32, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 182, 'runsScored': 5034, 'ballsFaced': 4793, "50's": 17, "100's": 16, 'wickets': 207, 'ballsBowled': 1677, 'runsGiven': 2435, "5's": 18, "10's": 1, 'exp': 57, 'name': 'P7'}]
#
# P7 successfully uploaded!
# [{'age': 33, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 64, 'runsScored': 3129, 'ballsFaced': 3005, "50's": 13, "100's": 11, 'wickets': 0, 'ballsBowled': 14, 'runsGiven': 32, "5's": 0, "10's": 0, 'exp': 37, 'name': 'P8'}]
#
# P8 successfully uploaded!
# [{'age': 33, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 226, 'runsScored': 6221, 'ballsFaced': 5937, "50's": 28, "100's": 16, 'wickets': 234, 'ballsBowled': 6585, 'runsGiven': 8615, "5's": 15, "10's": 2, 'exp': 67, 'name': 'P9'}]
#
# P9 successfully uploaded!
# [{'age': 24, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 61, 'runsScored': 174, 'ballsFaced': 216, "50's": 0, "100's": 0, 'wickets': 141, 'ballsBowled': 4042, 'runsGiven': 4106, "5's": 3, "10's": 5, 'exp': 45, 'name': 'P10'}]
#
# P10 successfully uploaded!
# [{'age': 39, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 6, 'runsScored': 28, 'ballsFaced': 21, "50's": 0, "100's": 0, 'wickets': 14, 'ballsBowled': 137, 'runsGiven': 163, "5's": 1, "10's": 0, 'exp': 4, 'name': 'P11'}]
#
# P11 successfully uploaded!
# [{'age': 34, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 70, 'runsScored': 203, 'ballsFaced': 256, "50's": 0, "100's": 0, 'wickets': 197, 'ballsBowled': 5586, 'runsGiven': 6361, "5's": 0, "10's": 0, 'exp': 42, 'name': 'P12'}]
#
# P12 successfully uploaded!
# [{'age': 27, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 78, 'runsScored': 3250, 'ballsFaced': 3286, "50's": 10, "100's": 14, 'wickets': 2, 'ballsBowled': 30, 'runsGiven': 57, "5's": 0, "10's": 0, 'exp': 38, 'name': 'P13'}]
#
# P13 successfully uploaded!
# [{'age': 24, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 66, 'runsScored': 2343, 'ballsFaced': 2206, "50's": 10, "100's": 7, 'wickets': 2, 'ballsBowled': 94, 'runsGiven': 200, "5's": 0, "10's": 0, 'exp': 30, 'name': 'P14'}]
#
# P14 successfully uploaded!
# [{'age': 18, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 24, 'runsScored': 1296, 'ballsFaced': 1262, "50's": 1, "100's": 7, 'wickets': 0, 'ballsBowled': 25, 'runsGiven': 30, "5's": 0, "10's": 0, 'exp': 18, 'name': 'P15'}]
#
# P15 successfully uploaded!
# [{'age': 27, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 60, 'runsScored': 217, 'ballsFaced': 258, "50's": 0, "100's": 0, 'wickets': 142, 'ballsBowled': 1513, 'runsGiven': 1721, "5's": 9, "10's": 1, 'exp': 39, 'name': 'P16'}]
#
# P16 successfully uploaded!
# [{'age': 32, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 50, 'runsScored': 2009, 'ballsFaced': 1952, "50's": 7, "100's": 7, 'wickets': 0, 'ballsBowled': 74, 'runsGiven': 117, "5's": 0, "10's": 0, 'exp': 29, 'name': 'P17'}]
#
# P17 successfully uploaded!
# [{'age': 27, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 134, 'runsScored': 4925, 'ballsFaced': 4713, "50's": 13, "100's": 20, 'wickets': 2, 'ballsBowled': 7, 'runsGiven': 17, "5's": 0, "10's": 0, 'exp': 47, 'name': 'P18'}]
#
# P18 successfully uploaded!
# [{'age': 39, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 232, 'runsScored': 7285, 'ballsFaced': 6919, "50's": 29, "100's": 24, 'wickets': 461, 'ballsBowled': 15266, 'runsGiven': 16538, "5's": 17, "10's": 14, 'exp': 79, 'name': 'P19'}]
#
# P19 successfully uploaded!
# [{'age': 18, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 6, 'runsScored': 523, 'ballsFaced': 515, "50's": 3, "100's": 2, 'wickets': 1, 'ballsBowled': 29, 'runsGiven': 87, "5's": 0, "10's": 0, 'exp': 10, 'name': 'P20'}]
#
# P20 successfully uploaded!
# [{'age': 19, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 20, 'runsScored': 57, 'ballsFaced': 85, "50's": 0, "100's": 0, 'wickets': 35, 'ballsBowled': 1090, 'runsGiven': 1336, "5's": 4, "10's": 1, 'exp': 14, 'name': 'P21'}]
#
# P21 successfully uploaded!
# [{'age': 40, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 142, 'runsScored': 5905, 'ballsFaced': 5680, "50's": 18, "100's": 21, 'wickets': 2, 'ballsBowled': 59, 'runsGiven': 77, "5's": 0, "10's": 0, 'exp': 47, 'name': 'P22'}]
#
# P22 successfully uploaded!
# [{'age': 18, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 10, 'runsScored': 296, 'ballsFaced': 301, "50's": 2, "100's": 0, 'wickets': 19, 'ballsBowled': 559, 'runsGiven': 679, "5's": 0, "10's": 0, 'exp': 6, 'name': 'P23'}]
#
# P23 successfully uploaded!
# [{'age': 22, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 72, 'runsScored': 1908, 'ballsFaced': 1869, "50's": 10, "100's": 4, 'wickets': 130, 'ballsBowled': 1340, 'runsGiven': 1366, "5's": 3, "10's": 4, 'exp': 37, 'name': 'P24'}]
#
# P24 successfully uploaded!
# [{'age': 34, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 164, 'runsScored': 6930, 'ballsFaced': 6859, "50's": 25, "100's": 28, 'wickets': 0, 'ballsBowled': 65, 'runsGiven': 106, "5's": 0, "10's": 0, 'exp': 56, 'name': 'P25'}]
#
# P25 successfully uploaded!
# [{'age': 30, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 28, 'runsScored': 33, 'ballsFaced': 72, "50's": 0, "100's": 0, 'wickets': 54, 'ballsBowled': 1793, 'runsGiven': 1806, "5's": 1, "10's": 3, 'exp': 21, 'name': 'P26'}]
#
# P26 successfully uploaded!
# [{'age': 31, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 196, 'runsScored': 503, 'ballsFaced': 640, "50's": 0, "100's": 0, 'wickets': 453, 'ballsBowled': 4606, 'runsGiven': 5216, "5's": 56, "10's": 10, 'exp': 63, 'name': 'P27'}]
#
# P27 successfully uploaded!
# [{'age': 26, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 84, 'runsScored': 3067, 'ballsFaced': 3012, "50's": 18, "100's": 7, 'wickets': 114, 'ballsBowled': 1048, 'runsGiven': 1214, "5's": 10, "10's": 1, 'exp': 42, 'name': 'P28'}]
#
# P28 successfully uploaded!
# [{'age': 40, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 332, 'runsScored': 13650, 'ballsFaced': 13307, "50's": 60, "100's": 49, 'wickets': 1, 'ballsBowled': 39, 'runsGiven': 156, "5's": 0, "10's": 0, 'exp': 87, 'name': 'P29'}]
#
# P29 successfully uploaded!
# [{'age': 38, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 297, 'runsScored': 7793, 'ballsFaced': 7596, "50's": 38, "100's": 16, 'wickets': 531, 'ballsBowled': 6889, 'runsGiven': 9742, "5's": 64, "10's": 15, 'exp': 77, 'name': 'P30'}]
#
# P30 successfully uploaded!
# [{'age': 25, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 30, 'runsScored': 808, 'ballsFaced': 768, "50's": 4, "100's": 2, 'wickets': 34, 'ballsBowled': 1362, 'runsGiven': 1884, "5's": 0, "10's": 1, 'exp': 15, 'name': 'P31'}]
#
# P31 successfully uploaded!
# [{'age': 22, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 63, 'runsScored': 1661, 'ballsFaced': 1654, "50's": 9, "100's": 3, 'wickets': 78, 'ballsBowled': 2466, 'runsGiven': 2954, "5's": 5, "10's": 4, 'exp': 33, 'name': 'P32'}]
#
# P32 successfully uploaded!
# [{'age': 23, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 41, 'runsScored': 1467, 'ballsFaced': 1425, "50's": 6, "100's": 5, 'wickets': 0, 'ballsBowled': 0, 'runsGiven': 0, "5's": 0, "10's": 0, 'exp': 21, 'name': 'P33'}]
#
# P33 successfully uploaded!
# [{'age': 28, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 11, 'runsScored': 481, 'ballsFaced': 476, "50's": 5, "100's": 0, 'wickets': 1, 'ballsBowled': 51, 'runsGiven': 121, "5's": 0, "10's": 0, 'exp': 8, 'name': 'P34'}]
#
# P34 successfully uploaded!
# [{'age': 26, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 78, 'runsScored': 1634, 'ballsFaced': 1680, "50's": 7, "100's": 3, 'wickets': 135, 'ballsBowled': 3159, 'runsGiven': 4628, "5's": 10, "10's": 1, 'exp': 39, 'name': 'P35'}]
#
# P35 successfully uploaded!
# [{'age': 36, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 93, 'runsScored': 3859, 'ballsFaced': 3755, "50's": 13, "100's": 13, 'wickets': 1, 'ballsBowled': 36, 'runsGiven': 48, "5's": 0, "10's": 0, 'exp': 39, 'name': 'P36'}]
#
# P36 successfully uploaded!
# [{'age': 31, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 160, 'runsScored': 474, 'ballsFaced': 586, "50's": 0, "100's": 0, 'wickets': 246, 'ballsBowled': 5092, 'runsGiven': 5284, "5's": 4, "10's": 8, 'exp': 59, 'name': 'P37'}]
#
# P37 successfully uploaded!
# [{'age': 26, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 29, 'runsScored': 989, 'ballsFaced': 994, "50's": 6, "100's": 2, 'wickets': 30, 'ballsBowled': 647, 'runsGiven': 873, "5's": 3, "10's": 1, 'exp': 18, 'name': 'P38'}]
#
# P38 successfully uploaded!
# [{'age': 20, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 26, 'runsScored': 82, 'ballsFaced': 107, "50's": 0, "100's": 0, 'wickets': 70, 'ballsBowled': 1166, 'runsGiven': 1233, "5's": 8, "10's": 2, 'exp': 24, 'name': 'P39'}]
#
# P39 successfully uploaded!
# [{'age': 25, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 54, 'runsScored': 133, 'ballsFaced': 165, "50's": 0, "100's": 0, 'wickets': 89, 'ballsBowled': 1847, 'runsGiven': 2284, "5's": 2, "10's": 0, 'exp': 29, 'name': 'P40'}]
#
# P40 successfully uploaded!
# [{'age': 37, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 270, 'runsScored': 11232, 'ballsFaced': 10829, "50's": 38, "100's": 46, 'wickets': 2, 'ballsBowled': 46, 'runsGiven': 129, "5's": 0, "10's": 0, 'exp': 81, 'name': 'P41'}]
#
# P41 successfully uploaded!
# [{'age': 21, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 41, 'runsScored': 118, 'ballsFaced': 156, "50's": 0, "100's": 0, 'wickets': 100, 'ballsBowled': 1148, 'runsGiven': 1281, "5's": 5, "10's": 6, 'exp': 34, 'name': 'P42'}]
#
# P42 successfully uploaded!
# [{'age': 34, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 235, 'runsScored': 8908, 'ballsFaced': 8353, "50's": 37, "100's": 30, 'wickets': 0, 'ballsBowled': 5, 'runsGiven': 13, "5's": 0, "10's": 0, 'exp': 68, 'name': 'P43'}]
#
# P43 successfully uploaded!
# [{'age': 33, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 206, 'runsScored': 8627, 'ballsFaced': 8401, "50's": 28, "100's": 36, 'wickets': 0, 'ballsBowled': 51, 'runsGiven': 93, "5's": 0, "10's": 0, 'exp': 67, 'name': 'P44'}]
#
# P44 successfully uploaded!
# [{'age': 30, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 23, 'runsScored': 44, 'ballsFaced': 73, "50's": 0, "100's": 0, 'wickets': 67, 'ballsBowled': 1297, 'runsGiven': 1491, "5's": 7, "10's": 2, 'exp': 23, 'name': 'P45'}]
#
# P45 successfully uploaded!
# [{'age': 34, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 84, 'runsScored': 2905, 'ballsFaced': 2918, "50's": 4, "100's": 15, 'wickets': 0, 'ballsBowled': 32, 'runsGiven': 103, "5's": 0, "10's": 0, 'exp': 31, 'name': 'P46'}]
#
# P46 successfully uploaded!
# [{'age': 23, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 22, 'runsScored': 920, 'ballsFaced': 918, "50's": 2, "100's": 5, 'wickets': 0, 'ballsBowled': 79, 'runsGiven': 176, "5's": 0, "10's": 0, 'exp': 15, 'name': 'P47'}]
#
# P47 successfully uploaded!
# [{'age': 37, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 139, 'runsScored': 7423, 'ballsFaced': 7194, "50's": 14, "100's": 35, 'wickets': 0, 'ballsBowled': 73, 'runsGiven': 180, "5's": 0, "10's": 0, 'exp': 54, 'name': 'P48'}]
#
# P48 successfully uploaded!
# [{'age': 22, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 7, 'runsScored': 142, 'ballsFaced': 152, "50's": 1, "100's": 0, 'wickets': 14, 'ballsBowled': 500, 'runsGiven': 728, "5's": 1, "10's": 0, 'exp': 5, 'name': 'P49'}]
#
# P49 successfully uploaded!
# [{'age': 32, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 209, 'runsScored': 676, 'ballsFaced': 837, "50's": 0, "100's": 0, 'wickets': 442, 'ballsBowled': 4154, 'runsGiven': 4675, "5's": 10, "10's": 6, 'exp': 64, 'name': 'P50'}]
#
# P50 successfully uploaded!
# [{'age': 21, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 13, 'runsScored': 558, 'ballsFaced': 573, "50's": 1, "100's": 3, 'wickets': 0, 'ballsBowled': 93, 'runsGiven': 211, "5's": 0, "10's": 0, 'exp': 10, 'name': 'P51'}]
#
# P51 successfully uploaded!
# [{'age': 21, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 20, 'runsScored': 742, 'ballsFaced': 774, "50's": 3, "100's": 3, 'wickets': 2, 'ballsBowled': 88, 'runsGiven': 127, "5's": 0, "10's": 0, 'exp': 14, 'name': 'P52'}]
#
# P52 successfully uploaded!
# [{'age': 35, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 222, 'runsScored': 8491, 'ballsFaced': 8096, "50's": 31, "100's": 30, 'wickets': 0, 'ballsBowled': 18, 'runsGiven': 26, "5's": 0, "10's": 0, 'exp': 67, 'name': 'P53'}]
#
# P53 successfully uploaded!
# [{'age': 40, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 173, 'runsScored': 4789, 'ballsFaced': 4805, "50's": 20, "100's": 11, 'wickets': 274, 'ballsBowled': 8169, 'runsGiven': 8713, "5's": 4, "10's": 1, 'exp': 60, 'name': 'P54'}]
#
# P54 successfully uploaded!
# [{'age': 20, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 3, 'runsScored': 74, 'ballsFaced': 70, "50's": 0, "100's": 0, 'wickets': 5, 'ballsBowled': 196, 'runsGiven': 222, "5's": 0, "10's": 0, 'exp': 1, 'name': 'P55'}]
#
# P55 successfully uploaded!
# [{'age': 34, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 69, 'runsScored': 2763, 'ballsFaced': 2708, "50's": 5, "100's": 14, 'wickets': 1, 'ballsBowled': 47, 'runsGiven': 116, "5's": 0, "10's": 0, 'exp': 30, 'name': 'P56'}]
#
# P56 successfully uploaded!
# [{'age': 21, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 44, 'runsScored': 1578, 'ballsFaced': 1514, "50's": 4, "100's": 7, 'wickets': 0, 'ballsBowled': 66, 'runsGiven': 90, "5's": 0, "10's": 0, 'exp': 24, 'name': 'P57'}]
#
# P57 successfully uploaded!
# [{'age': 40, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 127, 'runsScored': 306, 'ballsFaced': 451, "50's": 0, "100's": 0, 'wickets': 203, 'ballsBowled': 3557, 'runsGiven': 3607, "5's": 14, "10's": 10, 'exp': 59, 'name': 'P58'}]
#
# P58 successfully uploaded!
# [{'age': 27, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 99, 'runsScored': 2566, 'ballsFaced': 2518, "50's": 14, "100's": 6, 'wickets': 169, 'ballsBowled': 4836, 'runsGiven': 6266, "5's": 0, "10's": 5, 'exp': 45, 'name': 'P59'}]
#
# P59 successfully uploaded!
# [{'age': 19, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 4, 'runsScored': 26, 'ballsFaced': 36, "50's": 0, "100's": 0, 'wickets': 5, 'ballsBowled': 70, 'runsGiven': 90, "5's": 0, "10's": 0, 'exp': 1, 'name': 'P60'}]
#
# P60 successfully uploaded!
# [{'age': 31, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 126, 'runsScored': 5653, 'ballsFaced': 5078, "50's": 16, "100's": 24, 'wickets': 0, 'ballsBowled': 41, 'runsGiven': 99, "5's": 0, "10's": 0, 'exp': 46, 'name': 'P61'}]
#
# P61 successfully uploaded!
# [{'age': 17, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 23, 'runsScored': 1161, 'ballsFaced': 1118, "50's": 1, "100's": 6, 'wickets': 1, 'ballsBowled': 70, 'runsGiven': 248, "5's": 0, "10's": 0, 'exp': 18, 'name': 'P62'}]
#
# P62 successfully uploaded!
# [{'age': 18, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 31, 'runsScored': 68, 'ballsFaced': 105, "50's": 0, "100's": 0, 'wickets': 73, 'ballsBowled': 1013, 'runsGiven': 1077, "5's": 5, "10's": 2, 'exp': 23, 'name': 'P63'}]
#
# P63 successfully uploaded!
# [{'age': 33, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 189, 'runsScored': 607, 'ballsFaced': 761, "50's": 0, "100's": 0, 'wickets': 390, 'ballsBowled': 3183, 'runsGiven': 3495, "5's": 22, "10's": 19, 'exp': 63, 'name': 'P64'}]
#
# P64 successfully uploaded!
# [{'age': 25, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 32, 'runsScored': 921, 'ballsFaced': 947, "50's": 3, "100's": 3, 'wickets': 32, 'ballsBowled': 1152, 'runsGiven': 1600, "5's": 4, "10's": 0, 'exp': 18, 'name': 'P65'}]
#
# P65 successfully uploaded!
# [{'age': 26, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 12, 'runsScored': 36, 'ballsFaced': 47, "50's": 0, "100's": 0, 'wickets': 35, 'ballsBowled': 1150, 'runsGiven': 1415, "5's": 2, "10's": 0, 'exp': 11, 'name': 'P66'}]
#
# P66 successfully uploaded!
# [{'age': 35, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 37, 'runsScored': 99, 'ballsFaced': 151, "50's": 0, "100's": 0, 'wickets': 91, 'ballsBowled': 280, 'runsGiven': 292, "5's": 10, "10's": 1, 'exp': 24, 'name': 'P67'}]
#
# P67 successfully uploaded!
# [{'age': 21, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 12, 'runsScored': 44, 'ballsFaced': 64, "50's": 0, "100's": 0, 'wickets': 27, 'ballsBowled': 144, 'runsGiven': 155, "5's": 3, "10's": 0, 'exp': 7, 'name': 'P68'}]
#
# P68 successfully uploaded!
# [{'age': 23, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 50, 'runsScored': 1573, 'ballsFaced': 1527, "50's": 7, "100's": 6, 'wickets': 2, 'ballsBowled': 9, 'runsGiven': 24, "5's": 0, "10's": 0, 'exp': 25, 'name': 'P69'}]
#
# P69 successfully uploaded!
# [{'age': 20, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 16, 'runsScored': 52, 'ballsFaced': 60, "50's": 0, "100's": 0, 'wickets': 33, 'ballsBowled': 744, 'runsGiven': 892, "5's": 0, "10's": 1, 'exp': 11, 'name': 'P70'}]
#
# P70 successfully uploaded!
# [{'age': 40, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 100, 'runsScored': 2810, 'ballsFaced': 2598, "50's": 8, "100's": 9, 'wickets': 200, 'ballsBowled': 1512, 'runsGiven': 2188, "5's": 21, "10's": 4, 'exp': 49, 'name': 'P71'}]
#
# P71 successfully uploaded!
# [{'age': 18, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 4, 'runsScored': 49, 'ballsFaced': 61, "50's": 0, "100's": 0, 'wickets': 1, 'ballsBowled': 52, 'runsGiven': 128, "5's": 0, "10's": 0, 'exp': 1, 'name': 'P72'}]
#
# P72 successfully uploaded!
# [{'age': 25, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 42, 'runsScored': 1604, 'ballsFaced': 1575, "50's": 4, "100's": 8, 'wickets': 3, 'ballsBowled': 78, 'runsGiven': 220, "5's": 0, "10's": 0, 'exp': 24, 'name': 'P73'}]
#
# P73 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 69, 'runsScored': 2419, 'ballsFaced': 2362, "50's": 11, "100's": 8, 'wickets': 79, 'ballsBowled': 391, 'runsGiven': 426, "5's": 8, "10's": 2, 'exp': 33, 'name': 'P74'}]
#
# P74 successfully uploaded!
# [{'age': 31, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 65, 'runsScored': 3614, 'ballsFaced': 3197, "50's": 10, "100's": 16, 'wickets': 0, 'ballsBowled': 46, 'runsGiven': 52, "5's": 0, "10's": 0, 'exp': 39, 'name': 'P75'}]
#
# P75 successfully uploaded!
# [{'age': 18, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 7, 'runsScored': 4, 'ballsFaced': 15, "50's": 0, "100's": 0, 'wickets': 17, 'ballsBowled': 441, 'runsGiven': 547, "5's": 1, "10's": 0, 'exp': 5, 'name': 'P76'}]
#
# P76 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 34, 'runsScored': 1389, 'ballsFaced': 1361, "50's": 4, "100's": 5, 'wickets': 35, 'ballsBowled': 866, 'runsGiven': 1210, "5's": 4, "10's": 1, 'exp': 22, 'name': 'P77'}]
#
# P77 successfully uploaded!
# [{'age': 30, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 73, 'runsScored': 1476, 'ballsFaced': 1522, "50's": 10, "100's": 0, 'wickets': 88, 'ballsBowled': 4244, 'runsGiven': 6152, "5's": 2, "10's": 0, 'exp': 30, 'name': 'P78'}]
#
# P78 successfully uploaded!
# [{'age': 35, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 104, 'runsScored': 4849, 'ballsFaced': 4376, "50's": 16, "100's": 19, 'wickets': 0, 'ballsBowled': 60, 'runsGiven': 74, "5's": 0, "10's": 0, 'exp': 45, 'name': 'P79'}]
#
# P79 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 84, 'runsScored': 2308, 'ballsFaced': 2165, "50's": 7, "100's": 7, 'wickets': 92, 'ballsBowled': 744, 'runsGiven': 867, "5's": 0, "10's": 1, 'exp': 31, 'name': 'P80'}]
#
# P80 successfully uploaded!
# [{'age': 24, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 65, 'runsScored': 3188, 'ballsFaced': 2977, "50's": 6, "100's": 15, 'wickets': 0, 'ballsBowled': 1, 'runsGiven': 3, "5's": 0, "10's": 0, 'exp': 35, 'name': 'P81'}]
#
# P81 successfully uploaded!
# [{'age': 23, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 41, 'runsScored': 1598, 'ballsFaced': 1575, "50's": 7, "100's": 7, 'wickets': 0, 'ballsBowled': 86, 'runsGiven': 220, "5's": 0, "10's": 0, 'exp': 24, 'name': 'P82'}]
#
# P82 successfully uploaded!
# [{'age': 34, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 204, 'runsScored': 551, 'ballsFaced': 733, "50's": 0, "100's": 0, 'wickets': 434, 'ballsBowled': 10824, 'runsGiven': 11165, "5's": 29, "10's": 3, 'exp': 75, 'name': 'P83'}]
#
# P83 successfully uploaded!
# [{'age': 26, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 99, 'runsScored': 3716, 'ballsFaced': 3642, "50's": 20, "100's": 11, 'wickets': 1, 'ballsBowled': 20, 'runsGiven': 58, "5's": 0, "10's": 0, 'exp': 41, 'name': 'P84'}]
#
# P84 successfully uploaded!
# [{'age': 24, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 52, 'runsScored': 1954, 'ballsFaced': 1780, "50's": 5, "100's": 8, 'wickets': 0, 'ballsBowled': 86, 'runsGiven': 115, "5's": 0, "10's": 0, 'exp': 25, 'name': 'P85'}]
#
# P85 successfully uploaded!
# [{'age': 25, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 4, 'runsScored': 104, 'ballsFaced': 110, "50's": 0, "100's": 0, 'wickets': 7, 'ballsBowled': 158, 'runsGiven': 226, "5's": 0, "10's": 0, 'exp': 2, 'name': 'P86'}]
#
# P86 successfully uploaded!
# [{'age': 36, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 1, 'runsScored': 0, 'ballsFaced': 0, "50's": 0, "100's": 0, 'wickets': 2, 'ballsBowled': 71, 'runsGiven': 193, "5's": 0, "10's": 0, 'exp': 0, 'name': 'P87'}]
#
# P87 successfully uploaded!
# [{'age': 35, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 160, 'runsScored': 4564, 'ballsFaced': 4230, "50's": 19, "100's": 11, 'wickets': 245, 'ballsBowled': 5916, 'runsGiven': 7940, "5's": 8, "10's": 1, 'exp': 57, 'name': 'P88'}]
#
# P88 successfully uploaded!
# [{'age': 37, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 70, 'runsScored': 2522, 'ballsFaced': 2434, "50's": 10, "100's": 9, 'wickets': 2, 'ballsBowled': 100, 'runsGiven': 144, "5's": 0, "10's": 0, 'exp': 30, 'name': 'P89'}]
#
# P89 successfully uploaded!
# [{'age': 21, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 17, 'runsScored': 369, 'ballsFaced': 368, "50's": 0, "100's": 2, 'wickets': 30, 'ballsBowled': 662, 'runsGiven': 858, "5's": 2, "10's": 1, 'exp': 13, 'name': 'P90'}]
#
# P90 successfully uploaded!
# [{'age': 25, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 74, 'runsScored': 2555, 'ballsFaced': 2448, "50's": 11, "100's": 8, 'wickets': 144, 'ballsBowled': 2669, 'runsGiven': 2677, "5's": 17, "10's": 3, 'exp': 43, 'name': 'P91'}]
#
# P91 successfully uploaded!
# [{'age': 32, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 195, 'runsScored': 491, 'ballsFaced': 634, "50's": 0, "100's": 0, 'wickets': 497, 'ballsBowled': 10242, 'runsGiven': 11732, "5's": 18, "10's": 6, 'exp': 73, 'name': 'P92'}]
#
# P92 successfully uploaded!
# [{'age': 40, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 291, 'runsScored': 12002, 'ballsFaced': 11251, "50's": 39, "100's": 44, 'wickets': 1, 'ballsBowled': 75, 'runsGiven': 143, "5's": 0, "10's": 0, 'exp': 81, 'name': 'P93'}]
#
# P93 successfully uploaded!
# [{'age': 32, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 174, 'runsScored': 5176, 'ballsFaced': 5217, "50's": 28, "100's": 13, 'wickets': 289, 'ballsBowled': 2884, 'runsGiven': 4226, "5's": 20, "10's": 14, 'exp': 61, 'name': 'P94'}]
#
# P94 successfully uploaded!
# [{'age': 34, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 147, 'runsScored': 6710, 'ballsFaced': 6382, "50's": 18, "100's": 28, 'wickets': 0, 'ballsBowled': 53, 'runsGiven': 83, "5's": 0, "10's": 0, 'exp': 54, 'name': 'P95'}]
#
# P95 successfully uploaded!
# [{'age': 34, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 7, 'runsScored': 414, 'ballsFaced': 416, "50's": 2, "100's": 2, 'wickets': 1, 'ballsBowled': 19, 'runsGiven': 23, "5's": 0, "10's": 0, 'exp': 9, 'name': 'P96'}]
#
# P96 successfully uploaded!
# [{'age': 33, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 205, 'runsScored': 592, 'ballsFaced': 782, "50's": 0, "100's": 0, 'wickets': 440, 'ballsBowled': 11237, 'runsGiven': 13323, "5's": 15, "10's": 22, 'exp': 78, 'name': 'P97'}]
#
# P97 successfully uploaded!
# [{'age': 21, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 29, 'runsScored': 1421, 'ballsFaced': 1338, "50's": 4, "100's": 6, 'wickets': 0, 'ballsBowled': 73, 'runsGiven': 103, "5's": 0, "10's": 0, 'exp': 19, 'name': 'P98'}]
#
# P98 successfully uploaded!
# [{'age': 38, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 236, 'runsScored': 10186, 'ballsFaced': 9699, "50's": 34, "100's": 41, 'wickets': 0, 'ballsBowled': 76, 'runsGiven': 135, "5's": 0, "10's": 0, 'exp': 75, 'name': 'P99'}]
#
# P99 successfully uploaded!
# [{'age': 31, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 102, 'runsScored': 273, 'ballsFaced': 417, "50's": 0, "100's": 0, 'wickets': 176, 'ballsBowled': 259, 'runsGiven': 278, "5's": 7, "10's": 10, 'exp': 42, 'name': 'P100'}]
#
# P100 successfully uploaded!
# [{'age': 32, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 25, 'runsScored': 579, 'ballsFaced': 582, "50's": 2, "100's": 1, 'wickets': 0, 'ballsBowled': 87, 'runsGiven': 247, "5's": 0, "10's": 0, 'exp': 10, 'name': 'P101'}]
#
# P101 successfully uploaded!
# [{'age': 36, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 113, 'runsScored': 5268, 'ballsFaced': 4802, "50's": 20, "100's": 22, 'wickets': 0, 'ballsBowled': 75, 'runsGiven': 253, "5's": 0, "10's": 0, 'exp': 46, 'name': 'P102'}]
#
# P102 successfully uploaded!
# [{'age': 23, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 4, 'runsScored': 10, 'ballsFaced': 10, "50's": 0, "100's": 0, 'wickets': 9, 'ballsBowled': 95, 'runsGiven': 110, "5's": 1, "10's": 0, 'exp': 2, 'name': 'P103'}]
#
# P103 successfully uploaded!
# [{'age': 30, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 0, 'runsScored': 0, 'ballsFaced': 0, "50's": 0, "100's": 0, 'wickets': 0, 'ballsBowled': 0, 'runsGiven': 0, "5's": 0, "10's": 0, 'exp': 0, 'name': 'P104'}]
#
# P104 successfully uploaded!
# [{'age': 38, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 138, 'runsScored': 365, 'ballsFaced': 427, "50's": 0, "100's": 0, 'wickets': 320, 'ballsBowled': 1102, 'runsGiven': 1362, "5's": 37, "10's": 9, 'exp': 52, 'name': 'P105'}]
#
# P105 successfully uploaded!
# [{'age': 39, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 271, 'runsScored': 11176, 'ballsFaced': 10947, "50's": 47, "100's": 38, 'wickets': 2, 'ballsBowled': 81, 'runsGiven': 122, "5's": 0, "10's": 0, 'exp': 81, 'name': 'P106'}]
#
# P106 successfully uploaded!
# [{'age': 25, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 18, 'runsScored': 622, 'ballsFaced': 541, "50's": 2, "100's": 2, 'wickets': 2, 'ballsBowled': 26, 'runsGiven': 68, "5's": 0, "10's": 0, 'exp': 11, 'name': 'P107'}]
#
# P107 successfully uploaded!
# [{'age': 31, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 83, 'runsScored': 4400, 'ballsFaced': 4210, "50's": 13, "100's": 20, 'wickets': 2, 'ballsBowled': 5, 'runsGiven': 12, "5's": 0, "10's": 0, 'exp': 44, 'name': 'P108'}]
#
# P108 successfully uploaded!
# [{'age': 27, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 128, 'runsScored': 5900, 'ballsFaced': 5613, "50's": 18, "100's": 25, 'wickets': 0, 'ballsBowled': 76, 'runsGiven': 253, "5's": 0, "10's": 0, 'exp': 46, 'name': 'P109'}]
#
# P109 successfully uploaded!
# [{'age': 20, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 33, 'runsScored': 1376, 'ballsFaced': 1418, "50's": 3, "100's": 6, 'wickets': 0, 'ballsBowled': 100, 'runsGiven': 304, "5's": 0, "10's": 0, 'exp': 20, 'name': 'P110'}]
#
# P110 successfully uploaded!
# [{'age': 38, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 285, 'runsScored': 759, 'ballsFaced': 963, "50's": 0, "100's": 0, 'wickets': 853, 'ballsBowled': 15355, 'runsGiven': 18925, "5's": 64, "10's": 31, 'exp': 85, 'name': 'P111'}]
#
# P111 successfully uploaded!
# [{'age': 39, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 28, 'runsScored': 1588, 'ballsFaced': 1506, "50's": 4, "100's": 9, 'wickets': 0, 'ballsBowled': 72, 'runsGiven': 263, "5's": 0, "10's": 0, 'exp': 23, 'name': 'P112'}]
#
# P112 successfully uploaded!
# [{'age': 17, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 18, 'runsScored': 86, 'ballsFaced': 91, "50's": 0, "100's": 0, 'wickets': 46, 'ballsBowled': 1041, 'runsGiven': 1251, "5's": 2, "10's": 0, 'exp': 16, 'name': 'P113'}]
#
# P113 successfully uploaded!
# [{'age': 33, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 89, 'runsScored': 3968, 'ballsFaced': 3694, "50's": 14, "100's": 16, 'wickets': 0, 'ballsBowled': 53, 'runsGiven': 147, "5's": 0, "10's": 0, 'exp': 40, 'name': 'P114'}]
#
# P114 successfully uploaded!
# [{'age': 28, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 59, 'runsScored': 1749, 'ballsFaced': 1626, "50's": 5, "100's": 8, 'wickets': 93, 'ballsBowled': 157, 'runsGiven': 181, "5's": 1, "10's": 0, 'exp': 26, 'name': 'P115'}]
#
# P115 successfully uploaded!
# [{'age': 28, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 0, 'runsScored': 0, 'ballsFaced': 0, "50's": 0, "100's": 0, 'wickets': 0, 'ballsBowled': 0, 'runsGiven': 0, "5's": 0, "10's": 0, 'exp': 0, 'name': 'P116'}]
#
# P116 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 38, 'runsScored': 1074, 'ballsFaced': 945, "50's": 7, "100's": 1, 'wickets': 39, 'ballsBowled': 1531, 'runsGiven': 2074, "5's": 2, "10's": 0, 'exp': 20, 'name': 'P117'}]
#
# P117 successfully uploaded!
# [{'age': 20, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 28, 'runsScored': 999, 'ballsFaced': 948, "50's": 4, "100's": 2, 'wickets': 2, 'ballsBowled': 41, 'runsGiven': 54, "5's": 0, "10's": 0, 'exp': 14, 'name': 'P118'}]
#
# P118 successfully uploaded!
# [{'age': 37, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 318, 'runsScored': 8608, 'ballsFaced': 8558, "50's": 37, "100's": 22, 'wickets': 337, 'ballsBowled': 8847, 'runsGiven': 9028, "5's": 23, "10's": 9, 'exp': 81, 'name': 'P119'}]
#
# P119 successfully uploaded!
# [{'age': 30, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 88, 'runsScored': 3909, 'ballsFaced': 3643, "50's": 9, "100's": 15, 'wickets': 1, 'ballsBowled': 49, 'runsGiven': 119, "5's": 0, "10's": 0, 'exp': 39, 'name': 'P120'}]
#
# P120 successfully uploaded!
# [{'age': 38, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 11, 'runsScored': 493, 'ballsFaced': 462, "50's": 2, "100's": 2, 'wickets': 2, 'ballsBowled': 57, 'runsGiven': 138, "5's": 0, "10's": 0, 'exp': 9, 'name': 'P121'}]
#
# P121 successfully uploaded!
# [{'age': 22, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 41, 'runsScored': 1149, 'ballsFaced': 1142, "50's": 5, "100's": 4, 'wickets': 56, 'ballsBowled': 2287, 'runsGiven': 2306, "5's": 1, "10's": 2, 'exp': 24, 'name': 'P122'}]
#
# P122 successfully uploaded!
# [{'age': 33, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 140, 'runsScored': 400, 'ballsFaced': 509, "50's": 0, "100's": 0, 'wickets': 267, 'ballsBowled': 2561, 'runsGiven': 2633, "5's": 8, "10's": 1, 'exp': 51, 'name': 'P123'}]
#
# P123 successfully uploaded!
# [{'age': 31, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 72, 'runsScored': 2706, 'ballsFaced': 2702, "50's": 8, "100's": 10, 'wickets': 2, 'ballsBowled': 14, 'runsGiven': 26, "5's": 0, "10's": 0, 'exp': 30, 'name': 'P124'}]
#
# P124 successfully uploaded!
# [{'age': 23, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 60, 'runsScored': 1726, 'ballsFaced': 1642, "50's": 4, "100's": 5, 'wickets': 0, 'ballsBowled': 26, 'runsGiven': 78, "5's": 0, "10's": 0, 'exp': 25, 'name': 'P125'}]
#
# P125 successfully uploaded!
# [{'age': 37, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 248, 'runsScored': 10181, 'ballsFaced': 9859, "50's": 36, "100's": 41, 'wickets': 1, 'ballsBowled': 45, 'runsGiven': 150, "5's": 0, "10's": 0, 'exp': 76, 'name': 'P126'}]
#
# P126 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 64, 'runsScored': 1958, 'ballsFaced': 1959, "50's": 11, "100's": 4, 'wickets': 83, 'ballsBowled': 1745, 'runsGiven': 2054, "5's": 1, "10's": 4, 'exp': 33, 'name': 'P127'}]
#
# P127 successfully uploaded!
# [{'age': 32, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 88, 'runsScored': 277, 'ballsFaced': 383, "50's": 0, "100's": 0, 'wickets': 174, 'ballsBowled': 1114, 'runsGiven': 1149, "5's": 6, "10's": 6, 'exp': 45, 'name': 'P128'}]
#
# P128 successfully uploaded!
# [{'age': 33, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 173, 'runsScored': 6965, 'ballsFaced': 6654, "50's": 29, "100's": 21, 'wickets': 0, 'ballsBowled': 72, 'runsGiven': 198, "5's": 0, "10's": 0, 'exp': 57, 'name': 'P129'}]
#
# P129 successfully uploaded!
# [{'age': 36, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 106, 'runsScored': 3746, 'ballsFaced': 3605, "50's": 15, "100's": 11, 'wickets': 0, 'ballsBowled': 91, 'runsGiven': 331, "5's": 0, "10's": 0, 'exp': 41, 'name': 'P130'}]
#
# P130 successfully uploaded!
# [{'age': 37, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 144, 'runsScored': 433, 'ballsFaced': 590, "50's": 0, "100's": 0, 'wickets': 251, 'ballsBowled': 3523, 'runsGiven': 3927, "5's": 14, "10's": 2, 'exp': 57, 'name': 'P131'}]
#
# P131 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 60, 'runsScored': 1449, 'ballsFaced': 1504, "50's": 6, "100's": 3, 'wickets': 73, 'ballsBowled': 2259, 'runsGiven': 2461, "5's": 9, "10's": 1, 'exp': 31, 'name': 'P132'}]
#
# P132 successfully uploaded!
# [{'age': 23, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 47, 'runsScored': 1099, 'ballsFaced': 1107, "50's": 3, "100's": 3, 'wickets': 61, 'ballsBowled': 1690, 'runsGiven': 1818, "5's": 2, "10's": 1, 'exp': 25, 'name': 'P133'}]
#
# P133 successfully uploaded!
# [{'age': 21, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 72, 'runsScored': 259, 'ballsFaced': 264, "50's": 0, "100's": 0, 'wickets': 150, 'ballsBowled': 1175, 'runsGiven': 1195, "5's": 9, "10's": 5, 'exp': 44, 'name': 'P134'}]
#
# P134 successfully uploaded!
# [{'age': 20, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 26, 'runsScored': 787, 'ballsFaced': 757, "50's": 7, "100's": 1, 'wickets': 37, 'ballsBowled': 1370, 'runsGiven': 1915, "5's": 0, "10's": 2, 'exp': 15, 'name': 'P135'}]
#
# P135 successfully uploaded!
# [{'age': 23, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 9, 'runsScored': 200, 'ballsFaced': 181, "50's": 0, "100's": 1, 'wickets': 14, 'ballsBowled': 500, 'runsGiven': 528, "5's": 1, "10's": 0, 'exp': 6, 'name': 'P136'}]
#
# P136 successfully uploaded!
# [{'age': 27, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 44, 'runsScored': 158, 'ballsFaced': 161, "50's": 0, "100's": 0, 'wickets': 90, 'ballsBowled': 2124, 'runsGiven': 2314, "5's": 2, "10's": 0, 'exp': 28, 'name': 'P137'}]
#
# P137 successfully uploaded!
# [{'age': 27, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 140, 'runsScored': 5122, 'ballsFaced': 4921, "50's": 20, "100's": 18, 'wickets': 0, 'ballsBowled': 20, 'runsGiven': 49, "5's": 0, "10's": 0, 'exp': 47, 'name': 'P138'}]
#
# P138 successfully uploaded!
# [{'age': 21, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 34, 'runsScored': 663, 'ballsFaced': 665, "50's": 2, "100's": 2, 'wickets': 39, 'ballsBowled': 1911, 'runsGiven': 2588, "5's": 2, "10's": 2, 'exp': 19, 'name': 'P139'}]
#
# P139 successfully uploaded!
# [{'age': 34, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 207, 'runsScored': 8369, 'ballsFaced': 8170, "50's": 28, "100's": 34, 'wickets': 4, 'ballsBowled': 49, 'runsGiven': 68, "5's": 0, "10's": 0, 'exp': 67, 'name': 'P140'}]
#
# P140 successfully uploaded!
# [{'age': 28, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 106, 'runsScored': 4640, 'ballsFaced': 4595, "50's": 14, "100's": 23, 'wickets': 0, 'ballsBowled': 60, 'runsGiven': 153, "5's": 0, "10's": 0, 'exp': 45, 'name': 'P141'}]
#
# P141 successfully uploaded!
# [{'age': 36, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 37, 'runsScored': 658, 'ballsFaced': 703, "50's": 1, "100's": 1, 'wickets': 56, 'ballsBowled': 2214, 'runsGiven': 3149, "5's": 2, "10's": 1, 'exp': 19, 'name': 'P142'}]
#
# P142 successfully uploaded!
# [{'age': 30, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 13, 'runsScored': 528, 'ballsFaced': 551, "50's": 1, "100's": 2, 'wickets': 0, 'ballsBowled': 65, 'runsGiven': 73, "5's": 0, "10's": 0, 'exp': 9, 'name': 'P143'}]
#
# P143 successfully uploaded!
# [{'age': 20, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 8, 'runsScored': 445, 'ballsFaced': 431, "50's": 0, "100's": 3, 'wickets': 2, 'ballsBowled': 98, 'runsGiven': 273, "5's": 0, "10's": 0, 'exp': 8, 'name': 'P144'}]
#
# P144 successfully uploaded!
# [{'age': 29, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 76, 'runsScored': 2776, 'ballsFaced': 2737, "50's": 10, "100's": 11, 'wickets': 1, 'ballsBowled': 37, 'runsGiven': 72, "5's": 0, "10's": 0, 'exp': 31, 'name': 'P145'}]
#
# P145 successfully uploaded!
# [{'age': 31, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 22, 'runsScored': 780, 'ballsFaced': 709, "50's": 2, "100's": 3, 'wickets': 0, 'ballsBowled': 30, 'runsGiven': 61, "5's": 0, "10's": 0, 'exp': 14, 'name': 'P146'}]
#
# P146 successfully uploaded!
# [{'age': 24, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 80, 'runsScored': 234, 'ballsFaced': 310, "50's": 0, "100's": 0, 'wickets': 228, 'ballsBowled': 1556, 'runsGiven': 1585, "5's": 21, "10's": 3, 'exp': 50, 'name': 'P147'}]
#
# P147 successfully uploaded!
# [{'age': 38, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 258, 'runsScored': 9636, 'ballsFaced': 9468, "50's": 33, "100's": 38, 'wickets': 1, 'ballsBowled': 71, 'runsGiven': 202, "5's": 0, "10's": 0, 'exp': 73, 'name': 'P148'}]
#
# P148 successfully uploaded!
# [{'age': 24, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 38, 'runsScored': 1636, 'ballsFaced': 1577, "50's": 6, "100's": 7, 'wickets': 3, 'ballsBowled': 49, 'runsGiven': 120, "5's": 0, "10's": 0, 'exp': 24, 'name': 'P149'}]
#
# P149 successfully uploaded!
# [{'age': 26, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 47, 'runsScored': 1812, 'ballsFaced': 1862, "50's": 4, "100's": 8, 'wickets': 0, 'ballsBowled': 68, 'runsGiven': 108, "5's": 0, "10's": 0, 'exp': 24, 'name': 'P150'}]
#
# P150 successfully uploaded!
# [{'age': 30, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 0, 'runsScored': 0, 'ballsFaced': 0, "50's": 0, "100's": 0, 'wickets': 0, 'ballsBowled': 0, 'runsGiven': 0, "5's": 0, "10's": 0, 'exp': 0, 'name': 'P151'}]
#
# P151 successfully uploaded!
# [{'age': 19, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 31, 'runsScored': 1751, 'ballsFaced': 1538, "50's": 3, "100's": 9, 'wickets': 0, 'ballsBowled': 84, 'runsGiven': 98, "5's": 0, "10's": 0, 'exp': 22, 'name': 'P152'}]
#
# P152 successfully uploaded!
# [{'age': 35, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 96, 'runsScored': 3999, 'ballsFaced': 3798, "50's": 11, "100's": 16, 'wickets': 2, 'ballsBowled': 39, 'runsGiven': 86, "5's": 0, "10's": 0, 'exp': 40, 'name': 'P153'}]
#
# P153 successfully uploaded!
# [{'age': 26, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 41, 'runsScored': 1297, 'ballsFaced': 1366, "50's": 4, "100's": 3, 'wickets': 0, 'ballsBowled': 51, 'runsGiven': 131, "5's": 0, "10's": 0, 'exp': 19, 'name': 'P154'}]
#
# P154 successfully uploaded!
# [{'age': 29, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 91, 'runsScored': 231, 'ballsFaced': 323, "50's": 0, "100's": 0, 'wickets': 163, 'ballsBowled': 3063, 'runsGiven': 3255, "5's": 12, "10's": 7, 'exp': 53, 'name': 'P155'}]
#
# P155 successfully uploaded!
# [{'age': 17, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 29, 'runsScored': 35, 'ballsFaced': 59, "50's": 0, "100's": 0, 'wickets': 86, 'ballsBowled': 1742, 'runsGiven': 2046, "5's": 4, "10's": 5, 'exp': 33, 'name': 'P156'}]
#
# P156 successfully uploaded!
# [{'age': 25, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 20, 'runsScored': 806, 'ballsFaced': 743, "50's": 3, "100's": 3, 'wickets': 0, 'ballsBowled': 62, 'runsGiven': 98, "5's": 0, "10's": 0, 'exp': 14, 'name': 'P157'}]
#
# P157 successfully uploaded!
# [{'age': 21, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 43, 'runsScored': 1043, 'ballsFaced': 1125, "50's": 5, "100's": 2, 'wickets': 47, 'ballsBowled': 2206, 'runsGiven': 3209, "5's": 6, "10's": 1, 'exp': 25, 'name': 'P158'}]
#
# P158 successfully uploaded!
# [{'age': 39, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 335, 'runsScored': 8564, 'ballsFaced': 8517, "50's": 43, "100's": 20, 'wickets': 394, 'ballsBowled': 13224, 'runsGiven': 16880, "5's": 48, "10's": 6, 'exp': 87, 'name': 'P159'}]
#
# P159 successfully uploaded!
# ...
#
# P435 successfully uploaded!
# [{'age': 34, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 52, 'runsScored': 1526, 'ballsFaced': 1504, "50's": 5, "100's": 4, 'wickets': 80, 'ballsBowled': 596, 'runsGiven': 807, "5's": 10, "10's": 2, 'exp': 32, 'name': 'P436'}]
#
# P436 successfully uploaded!
# [{'age': 38, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 176, 'runsScored': 7004, 'ballsFaced': 6697, "50's": 25, "100's": 28, 'wickets': 0, 'ballsBowled': 15, 'runsGiven': 21, "5's": 0, "10's": 0, 'exp': 57, 'name': 'P437'}]
#
# P437 successfully uploaded!
# [{'age': 39, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 148, 'runsScored': 5885, 'ballsFaced': 5636, "50's": 29, "100's": 20, 'wickets': 0, 'ballsBowled': 16, 'runsGiven': 39, "5's": 0, "10's": 0, 'exp': 48, 'name': 'P438'}]
#
# P438 successfully uploaded!
# [{'age': 18, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 15, 'runsScored': 477, 'ballsFaced': 457, "50's": 3, "100's": 2, 'wickets': 0, 'ballsBowled': 52, 'runsGiven': 79, "5's": 0, "10's": 0, 'exp': 9, 'name': 'P439'}]
#
# P439 successfully uploaded!
# [{'age': 25, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 83, 'runsScored': 3073, 'ballsFaced': 2913, "50's": 14, "100's": 8, 'wickets': 3, 'ballsBowled': 58, 'runsGiven': 88, "5's": 0, "10's": 0, 'exp': 35, 'name': 'P440'}]
#
# P440 successfully uploaded!
# [{'age': 28, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 95, 'runsScored': 3933, 'ballsFaced': 3878, "50's": 7, "100's": 18, 'wickets': 0, 'ballsBowled': 25, 'runsGiven': 57, "5's": 0, "10's": 0, 'exp': 39, 'name': 'P441'}]
#
# P441 successfully uploaded!
# [{'age': 22, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 14, 'runsScored': 514, 'ballsFaced': 491, "50's": 1, "100's": 3, 'wickets': 0, 'ballsBowled': 75, 'runsGiven': 201, "5's": 0, "10's": 0, 'exp': 10, 'name': 'P442'}]
#
# P442 successfully uploaded!
# [{'age': 31, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 215, 'runsScored': 9927, 'ballsFaced': 9363, "50's": 34, "100's": 41, 'wickets': 0, 'ballsBowled': 6, 'runsGiven': 10, "5's": 0, "10's": 0, 'exp': 71, 'name': 'P443'}]
#
# P443 successfully uploaded!
# [{'age': 20, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 16, 'runsScored': 282, 'ballsFaced': 272, "50's": 0, "100's": 1, 'wickets': 22, 'ballsBowled': 1046, 'runsGiven': 1104, "5's": 1, "10's": 1, 'exp': 10, 'name': 'P444'}]
#
# P444 successfully uploaded!
# [{'age': 36, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 212, 'runsScored': 8919, 'ballsFaced': 8579, "50's": 23, "100's": 38, 'wickets': 1, 'ballsBowled': 88, 'runsGiven': 111, "5's": 0, "10's": 0, 'exp': 66, 'name': 'P445'}]
#
# P445 successfully uploaded!
# [{'age': 20, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 31, 'runsScored': 1380, 'ballsFaced': 1377, "50's": 3, "100's": 7, 'wickets': 4, 'ballsBowled': 45, 'runsGiven': 165, "5's": 0, "10's": 0, 'exp': 19, 'name': 'P446'}]
#
# P446 successfully uploaded!
# [{'age': 30, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 71, 'runsScored': 2402, 'ballsFaced': 2191, "50's": 6, "100's": 10, 'wickets': 75, 'ballsBowled': 3102, 'runsGiven': 3460, "5's": 3, "10's": 4, 'exp': 38, 'name': 'P447'}]
#
# P447 successfully uploaded!
# [{'age': 25, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 39, 'runsScored': 1125, 'ballsFaced': 1041, "50's": 4, "100's": 4, 'wickets': 42, 'ballsBowled': 186, 'runsGiven': 233, "5's": 1, "10's": 0, 'exp': 18, 'name': 'P448'}]
#
# P448 successfully uploaded!
# [{'age': 36, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 303, 'runsScored': 7874, 'ballsFaced': 7779, "50's": 31, "100's": 23, 'wickets': 374, 'ballsBowled': 4558, 'runsGiven': 4867, "5's": 10, "10's": 16, 'exp': 76, 'name': 'P449'}]
#
# P449 successfully uploaded!
# [{'age': 36, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 105, 'runsScored': 3711, 'ballsFaced': 3446, "50's": 14, "100's": 11, 'wickets': 4, 'ballsBowled': 67, 'runsGiven': 117, "5's": 0, "10's": 0, 'exp': 40, 'name': 'P450'}]
#
# P450 successfully uploaded!
# [{'age': 29, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 20, 'runsScored': 691, 'ballsFaced': 690, "50's": 1, "100's": 2, 'wickets': 40, 'ballsBowled': 829, 'runsGiven': 858, "5's": 1, "10's": 1, 'exp': 16, 'name': 'P451'}]
#
# P451 successfully uploaded!
# [{'age': 19, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 17, 'runsScored': 457, 'ballsFaced': 420, "50's": 0, "100's": 2, 'wickets': 18, 'ballsBowled': 624, 'runsGiven': 900, "5's": 1, "10's": 0, 'exp': 10, 'name': 'P452'}]
#
# P452 successfully uploaded!
# [{'age': 28, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 112, 'runsScored': 5675, 'ballsFaced': 5282, "50's": 13, "100's": 25, 'wickets': 2, 'ballsBowled': 60, 'runsGiven': 161, "5's": 0, "10's": 0, 'exp': 45, 'name': 'P453'}]
#
# P453 successfully uploaded!
# [{'age': 26, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 112, 'runsScored': 295, 'ballsFaced': 414, "50's": 0, "100's": 0, 'wickets': 281, 'ballsBowled': 6977, 'runsGiven': 7562, "5's": 12, "10's": 11, 'exp': 61, 'name': 'P454'}]
#
# P454 successfully uploaded!
# [{'age': 30, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 17, 'runsScored': 503, 'ballsFaced': 524, "50's": 1, "100's": 2, 'wickets': 0, 'ballsBowled': 20, 'runsGiven': 31, "5's": 0, "10's": 0, 'exp': 10, 'name': 'P455'}]
#
# P455 successfully uploaded!
# [{'age': 19, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 23, 'runsScored': 1044, 'ballsFaced': 1038, "50's": 3, "100's": 5, 'wickets': 1, 'ballsBowled': 45, 'runsGiven': 45, "5's": 0, "10's": 0, 'exp': 19, 'name': 'P456'}]
#
# P456 successfully uploaded!
# [{'age': 35, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 16, 'runsScored': 670, 'ballsFaced': 615, "50's": 1, "100's": 3, 'wickets': 1, 'ballsBowled': 5, 'runsGiven': 7, "5's": 0, "10's": 0, 'exp': 13, 'name': 'P457'}]
#
# P457 successfully uploaded!
# [{'age': 18, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 3, 'runsScored': 41, 'ballsFaced': 50, "50's": 0, "100's": 0, 'wickets': 1, 'ballsBowled': 27, 'runsGiven': 28, "5's": 0, "10's": 0, 'exp': 1, 'name': 'P458'}]
#
# P458 successfully uploaded!
# [{'age': 30, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 116, 'runsScored': 362, 'ballsFaced': 515, "50's": 0, "100's": 0, 'wickets': 264, 'ballsBowled': 6635, 'runsGiven': 7983, "5's": 10, "10's": 14, 'exp': 62, 'name': 'P459'}]
#
# P459 successfully uploaded!
# [{'age': 36, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'right hand', 'bowlingStyle': 'None', 'innings': 152, 'runsScored': 5897, 'ballsFaced': 5852, "50's": 13, "100's": 26, 'wickets': 0, 'ballsBowled': 9, 'runsGiven': 17, "5's": 0, "10's": 0, 'exp': 48, 'name': 'P460'}]
#
# P460 successfully uploaded!
# [{'age': 34, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 50, 'runsScored': 2192, 'ballsFaced': 2123, "50's": 8, "100's": 9, 'wickets': 2, 'ballsBowled': 24, 'runsGiven': 29, "5's": 0, "10's": 0, 'exp': 29, 'name': 'P461'}]
#
# P461 successfully uploaded!
# [{'age': 33, 'ptype': 'batsman', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 213, 'runsScored': 8727, 'ballsFaced': 8492, "50's": 34, "100's": 33, 'wickets': 2, 'ballsBowled': 31, 'runsGiven': 89, "5's": 0, "10's": 0, 'exp': 67, 'name': 'P462'}]
#
# P462 successfully uploaded!
# [{'age': 26, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 36, 'runsScored': 1951, 'ballsFaced': 1712, "50's": 3, "100's": 10, 'wickets': 0, 'ballsBowled': 45, 'runsGiven': 47, "5's": 0, "10's": 0, 'exp': 24, 'name': 'P463'}]
#
# P463 successfully uploaded!
# [{'age': 39, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 147, 'runsScored': 6244, 'ballsFaced': 6042, "50's": 22, "100's": 25, 'wickets': 3, 'ballsBowled': 68, 'runsGiven': 214, "5's": 0, "10's": 0, 'exp': 55, 'name': 'P464'}]
#
# P464 successfully uploaded!
# [{'age': 40, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 307, 'runsScored': 12208, 'ballsFaced': 11596, "50's": 37, "100's": 50, 'wickets': 0, 'ballsBowled': 46, 'runsGiven': 64, "5's": 0, "10's": 0, 'exp': 82, 'name': 'P465'}]
#
# P465 successfully uploaded!
# [{'age': 17, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 13, 'runsScored': 363, 'ballsFaced': 372, "50's": 1, "100's": 0, 'wickets': 23, 'ballsBowled': 983, 'runsGiven': 1116, "5's": 0, "10's": 0, 'exp': 7, 'name': 'P466'}]
#
# P466 successfully uploaded!
# [{'age': 18, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 10, 'runsScored': 306, 'ballsFaced': 287, "50's": 2, "100's": 1, 'wickets': 19, 'ballsBowled': 592, 'runsGiven': 856, "5's": 0, "10's": 0, 'exp': 6, 'name': 'P467'}]
#
# P467 successfully uploaded!
# [{'age': 22, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 10, 'runsScored': 317, 'ballsFaced': 330, "50's": 2, "100's": 0, 'wickets': 2, 'ballsBowled': 91, 'runsGiven': 266, "5's": 0, "10's": 0, 'exp': 7, 'name': 'P468'}]
#
# P468 successfully uploaded!
# [{'age': 32, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 120, 'runsScored': 3984, 'ballsFaced': 3750, "50's": 17, "100's": 11, 'wickets': 0, 'ballsBowled': 40, 'runsGiven': 132, "5's": 0, "10's": 0, 'exp': 42, 'name': 'P469'}]
#
# P469 successfully uploaded!
# [{'age': 24, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 62, 'runsScored': 167, 'ballsFaced': 200, "50's": 0, "100's": 0, 'wickets': 169, 'ballsBowled': 1195, 'runsGiven': 1282, "5's": 6, "10's": 2, 'exp': 40, 'name': 'P470'}]
#
# P470 successfully uploaded!
# [{'age': 37, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 150, 'runsScored': 5799, 'ballsFaced': 5463, "50's": 29, "100's": 18, 'wickets': 0, 'ballsBowled': 98, 'runsGiven': 220, "5's": 0, "10's": 0, 'exp': 49, 'name': 'P471'}]
#
# P471 successfully uploaded!
# [{'age': 37, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 85, 'runsScored': 3787, 'ballsFaced': 3605, "50's": 14, "100's": 15, 'wickets': 0, 'ballsBowled': 1, 'runsGiven': 2, "5's": 0, "10's": 0, 'exp': 40, 'name': 'P472'}]
#
# P472 successfully uploaded!
# [{'age': 17, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 16, 'runsScored': 27, 'ballsFaced': 35, "50's": 0, "100's": 0, 'wickets': 38, 'ballsBowled': 74, 'runsGiven': 88, "5's": 4, "10's": 1, 'exp': 11, 'name': 'P473'}]
#
# P473 successfully uploaded!
# [{'age': 32, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 64, 'runsScored': 2485, 'ballsFaced': 2417, "50's": 12, "100's": 8, 'wickets': 3, 'ballsBowled': 40, 'runsGiven': 65, "5's": 0, "10's": 0, 'exp': 29, 'name': 'P474'}]
#
# P474 successfully uploaded!
# [{'age': 22, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 75, 'runsScored': 3198, 'ballsFaced': 3032, "50's": 16, "100's": 12, 'wickets': 4, 'ballsBowled': 70, 'runsGiven': 134, "5's": 0, "10's": 0, 'exp': 39, 'name': 'P475'}]
#
# P475 successfully uploaded!
# [{'age': 30, 'ptype': 'bowler', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 6, 'runsScored': 21, 'ballsFaced': 27, "50's": 0, "100's": 0, 'wickets': 15, 'ballsBowled': 305, 'runsGiven': 361, "5's": 2, "10's": 0, 'exp': 6, 'name': 'P476'}]
#
# P476 successfully uploaded!
# [{'age': 27, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 55, 'runsScored': 1382, 'ballsFaced': 1286, "50's": 6, "100's": 3, 'wickets': 96, 'ballsBowled': 3969, 'runsGiven': 5470, "5's": 10, "10's": 0, 'exp': 32, 'name': 'P477'}]
#
# P477 successfully uploaded!
# [{'age': 23, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 0, 'runsScored': 0, 'ballsFaced': 0, "50's": 0, "100's": 0, 'wickets': 0, 'ballsBowled': 0, 'runsGiven': 0, "5's": 0, "10's": 0, 'exp': 0, 'name': 'P478'}]
#
# P478 successfully uploaded!
# [{'age': 33, 'ptype': 'wicketkeeperbatsman', 'battingStyle': 'left hand', 'bowlingStyle': 'None', 'innings': 215, 'runsScored': 8263, 'ballsFaced': 7815, "50's": 23, "100's": 34, 'wickets': 1, 'ballsBowled': 62, 'runsGiven': 158, "5's": 0, "10's": 0, 'exp': 66, 'name': 'P479'}]
#
# P479 successfully uploaded!
# [{'age': 26, 'ptype': 'batsman', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 9, 'runsScored': 344, 'ballsFaced': 281, "50's": 0, "100's": 2, 'wickets': 1, 'ballsBowled': 89, 'runsGiven': 160, "5's": 0, "10's": 0, 'exp': 6, 'name': 'P480'}]
#
# P480 successfully uploaded!
# [{'age': 32, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 220, 'runsScored': 6302, 'ballsFaced': 5920, "50's": 23, "100's": 17, 'wickets': 376, 'ballsBowled': 2887, 'runsGiven': 3331, "5's": 25, "10's": 10, 'exp': 65, 'name': 'P481'}]
#
# P481 successfully uploaded!
# [{'age': 21, 'ptype': 'allrounder', 'battingStyle': 'left hand', 'bowlingStyle': 'right hand', 'innings': 12, 'runsScored': 111, 'ballsFaced': 116, "50's": 0, "100's": 0, 'wickets': 14, 'ballsBowled': 384, 'runsGiven': 515, "5's": 1, "10's": 0, 'exp': 5, 'name': 'P482'}]
#
# P482 successfully uploaded!
# [{'age': 40, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 65, 'runsScored': 1982, 'ballsFaced': 1869, "50's": 7, "100's": 5, 'wickets': 110, 'ballsBowled': 2404, 'runsGiven': 3179, "5's": 0, "10's": 2, 'exp': 33, 'name': 'P483'}]
#
# P483 successfully uploaded!
# [{'age': 22, 'ptype': 'bowler', 'battingStyle': 'left hand', 'bowlingStyle': 'left hand', 'innings': 3, 'runsScored': 8, 'ballsFaced': 7, "50's": 0, "100's": 0, 'wickets': 9, 'ballsBowled': 65, 'runsGiven': 74, "5's": 0, "10's": 0, 'exp': 1, 'name': 'P484'}]
#
# P484 successfully uploaded!
# [{'age': 39, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'left hand', 'innings': 4, 'runsScored': 72, 'ballsFaced': 80, "50's": 0, "100's": 0, 'wickets': 5, 'ballsBowled': 224, 'runsGiven': 272, "5's": 0, "10's": 0, 'exp': 1, 'name': 'P485'}]
#
# P485 successfully uploaded!
# [{'age': 36, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 23, 'runsScored': 794, 'ballsFaced': 745, "50's": 3, "100's": 2, 'wickets': 35, 'ballsBowled': 568, 'runsGiven': 615, "5's": 4, "10's": 1, 'exp': 16, 'name': 'P486'}]
#
# P486 successfully uploaded!
# [{'age': 24, 'ptype': 'allrounder', 'battingStyle': 'right hand', 'bowlingStyle': 'right hand', 'innings': 61, 'runsScored': 1573, 'ballsFaced': 1611, "50's": 7, "100's": 4, 'wickets': 92, 'ballsBowled': 4413, 'runsGiven': 5433, "5's": 11, "10's": 0, 'exp': 34, 'name': 'P487'}]
#
# P487 successfully uploaded!
